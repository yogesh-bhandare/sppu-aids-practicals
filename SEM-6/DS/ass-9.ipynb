# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset("titanic")
titanic_clean = titanic.dropna(subset = ["age"])

# %%
# Step 2
# Step 4: Plot the box plot
plt.figure(figsize=(10, 6))  # Set the figure size for better visibility
sns.boxplot(data=titanic_clean, x='sex', hue='survived', palette='Set2')

# Step 5: Customize the plot
plt.title('Box Plot: Age Distribution by Gender and Survival Status')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.legend(title='Survived (0 = No, 1 = Yes)')
plt.grid(True)
plt.show()

# %%
# Step 3: Drop rows where 'age' is missing
# This is important because box plots cannot be drawn with NaN values
titanic_clean = titanic.dropna(subset=['age'])

# %%
# Step 4: Plot the box plot
plt.figure(figsize=(10, 6))  # Set the figure size for better visibility
sns.boxplot(data=titanic_clean, x='sex', y='age', hue='survived', palette='Set2')

# Step 5: Customize the plot
plt.title('Box Plot: Age Distribution by Gender and Survival Status')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.legend(title='Survived (0 = No, 1 = Yes)')
plt.grid(True)
plt.show()
